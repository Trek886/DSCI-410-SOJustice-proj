# %%
import pandas as pd
import numpy as np

# %%
raw_call = pd.read_csv("class_data_2023.csv")
raw_weather = pd.read_csv("Eugene Oregon 2023-08-10 to 2025-04-25.csv")
# Out:
# C:\Users\trema\AppData\Local\Temp\ipykernel_28360\2622061745.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   raw_call = pd.read_csv("class_data_2023.csv")

# %%
raw_call.head()
# Out:
#      yr service   inci_id                 calltime  case_id callsource  \
# 0  2023    LAW   23000008  2023-01-01 00:03:23.000      NaN       SELF
# 1  2023    LAW   23000013  2023-01-01 00:04:56.000      NaN       W911
# 2  2023    LAW   23000015  2023-01-01 00:05:55.000      NaN      PHONE
# 3  2023    LAW   23000019  2023-01-01 00:10:04.000      NaN       SELF
# 4  2023    LAW   23000021  2023-01-01 00:11:05.000      NaN       SELF
#
#                 nature closecode                        closed_as  \
# 0  SPEEDING MOTORCYCLE      UTC   UNIFORM TRAFFIC CITATION ISSUED
# 1    ILLEGAL FIREWORKS      REL          REFERRED TO OTHER AGENCY
# 2    CRIMINAL MISCHIEF      ADVI                          ADVISED
# 3         PATROL CHECK      PCHK                     PATROL CHECK
# 4         PATROL CHECK      PCHK                     PATROL CHECK
#
#    secs_to_disp  secs_to_arrv  secs_to_close  disp  arrv  beat priority  \
# ...

# %%
raw_weather.head()
# Out:
#      datetime  tempmax  tempmin  temp  feelslike   dew  humidity  precip  \
# 0  2023-08-10     83.9     62.9  72.8       72.5  54.5      55.6     0.0
# 1  2023-08-11     89.0     56.9  72.3       71.7  53.3      55.0     0.0
# 2  2023-08-12     91.1     58.0  74.6       74.0  54.2      52.8     0.0
# 3  2023-08-13    101.8     62.8  80.7       79.9  54.9      46.0     0.0
# 4  2023-08-14    102.0     65.7  83.3       82.6  55.3      41.9     0.0
#
#    precipprob  precipcover  ... windspeedmin  winddir  sealevelpressure  \
# 0           0          0.0  ...          0.5    309.1            1015.1
# 1           0          0.0  ...          0.0    311.9            1016.4
# 2           0          0.0  ...          0.4    317.4            1018.8
# 3           0          0.0  ...          0.2    312.8            1015.4
# 4           0          0.0  ...          0.0    329.0            1011.8
#
#    solarradiation  solarenergy  uvindex  severerisk        conditions  \
# ...

# %%
raw_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   datetime          625 non-null    object
#  1   tempmax           625 non-null    float64
#  2   tempmin           625 non-null    float64
#  3   temp              625 non-null    float64
#  4   feelslike         625 non-null    float64
#  5   dew               625 non-null    float64
#  6   humidity          625 non-null    float64
#  7   precip            625 non-null    float64
#  8   precipprob        625 non-null    int64
#  9   precipcover       625 non-null    float64
#  10  preciptype        298 non-null    object
#  11  snow              625 non-null    float64
#  12  snowdepth         625 non-null    float64
#  13  windgust          625 non-null    float64
#  14  windspeed         625 non-null    float64
#  15  windspeedmax      625 non-null    float64
# ...

# %%
raw_call.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135464 entries, 0 to 135463
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   yr             135464 non-null  int64
#  1   service        135464 non-null  object
#  2   inci_id        135464 non-null  int64
#  3   calltime       135464 non-null  object
#  4   case_id        20018 non-null   float64
#  5   callsource     135464 non-null  object
#  6   nature         135454 non-null  object
#  7   closecode      135464 non-null  object
#  8   closed_as      132932 non-null  object
#  9   secs_to_disp   94905 non-null   float64
#  10  secs_to_arrv   80815 non-null   float64
#  11  secs_to_close  135464 non-null  int64
#  12  disp           135464 non-null  int64
#  13  arrv           135464 non-null  int64
#  14  beat           135462 non-null  object
#  15  priority       135464 non-null  object
#  16  zip            135464 non-null  object
# ...

# %%
raw_call['PrimaryUnitCallSign'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\trema\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PrimaryUnitCallSign'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 raw_call['PrimaryUnitCallSign'].value_counts()
# ...

# %%
raw_call['Call_Created_Time'].max()
# Out:
# '8/9/23 9:59'
